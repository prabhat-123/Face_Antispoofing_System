# %% [markdown]
# <h1>Getting datasets from google drive to workspace </h1>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -r "/content/gdrive/MyDrive/final_antispoofing.zip" "/content"

# %%
import zipfile
archive = zipfile.ZipFile('/content/final_antispoofing.zip')
archive.extractall('/content')

# %% [markdown]
# <h1>Data Preprocessing </h1>

# %% [markdown]
# <h2> Four Steps </h2>
# <h3>Step 1: Create new directory structure for the datasets</h3>
# <h3>Step 2: Copying images into new directory structure </h3>
# <h3>Step 3: Dataset Exploration </h3>
# <h4> Step 4: Dataset Visualization </h3>

# %% [markdown]
# <h3>Step 1 </h1>

# %% [markdown]
# <h2>Original VS New Directory Structure</h2>

# %%
from IPython import display
print("Original Vs New Dataset Structure")
display.Image('original vs new_dataset.png')
# Out:
# Original Vs New Dataset Structure

# %%
dataset_dir = '/content/final_antispoofing'
train_dataset_dir = '/content/final_antispoofing/train'
test_dataset_dir = '/content/final_antispoofing/test'

# %%
import os
os.mkdir('/content/antispoofing_dataset')
os.mkdir('/content/antispoofing_dataset/train')
os.mkdir('/content/antispoofing_dataset/test')
os.mkdir('/content/antispoofing_dataset/train/real')
os.mkdir('/content/antispoofing_dataset/train/spoof')
os.mkdir('/content/antispoofing_dataset/test/real')
os.mkdir('/content/antispoofing_dataset/test/spoof')

# %%
train_dir='/content/antispoofing_dataset/train'
test_dir = '/content/antispoofing_dataset/test'

# %% [markdown]
# <h3>Step 2 </h3>

# %%
import shutil
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
def train_test_splits(data_directory):
  for split_type in os.listdir(data_directory):
    path_to_split_type = os.path.join(data_directory,split_type)
    for category in os.listdir(path_to_split_type):
      path_to_category = os.path.join(path_to_split_type,category)
      for subject in os.listdir(path_to_category):
        path_to_subject = os.path.join(path_to_category,subject)
        for img in os.listdir(path_to_subject):
          if split_type == 'train':
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(train_dir,category,img))
          else:
            shutil.copy(os.path.join(path_to_subject,img),os.path.join(test_dir,category,img))

# %%
train_test_splits(data_directory=dataset_dir)

# %% [markdown]
# <h3>Step 3 </h3>

# %% [markdown]
# <h3>Dataset Exploration </h3>

# %%
categories = ['real','spoof']

# %%
print("---------------------Exploring Training Datasets--------------------")
for category in categories:
  path = os.path.join(train_dir,category)
  if category == 'real':
    r1 = len(os.listdir(path))
  else:
    s1 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in training directory".format(r1+s1))

print("-----------------------Exploring Testing Datasets-------------------------")
for category in categories:
  path = os.path.join(test_dir,category)
  if category == 'real':
    r2 = len(os.listdir(path))
  else:
    s2 = len(os.listdir(path))
  print("There are {} images in {} directory".format(len(os.listdir(path)),category))
print("There are {} total images in testing directory".format(r2+s2))
# Out:
# ---------------------Exploring Training Datasets--------------------
# There are 2102 images in real directory
# There are 2118 images in spoof directory
# There are 4220 total images in training directory
# -----------------------Exploring Testing Datasets-------------------------
# There are 477 images in real directory
# There are 474 images in spoof directory
# There are 951 total images in testing directory

# %% [markdown]
# <h3>Step 4 : Dataset Visualization </h3>

# %%
def get_images(data_dir,number_of_samples):
  image_path = []
  for category in categories:
    path = os.path.join(data_dir,category)
    i = 1
    for img in os.listdir(path):
      if i > number_of_samples:
        break
      else:
        image_path.append(os.path.join(path,img))
        i += 1
  return image_path

# %%
def visualize_dataset(image_path,rows,cols):
  fig = plt.figure(figsize=(20,20))
  for i in range(1,rows * cols + 1):
    fig.add_subplot(rows,cols,i)
    img_array = cv2.imread(image_path[i-1])
    fig.subplots_adjust(hspace=1)
    plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
    plt.xlabel(image_path[i-1].split('/')[-2])
  plt.show()

# %%
training_image_path = get_images(data_dir= train_dir,number_of_samples=25)
print(training_image_path)
print(len(training_image_path))
# Out:
# ['/content/antispoofing_dataset/train/real/dfgyhjnmk16.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal18brightness1.19.jpg', '/content/antispoofing_dataset/train/real/fjkdj49.jpg', '/content/antispoofing_dataset/train/real/WIN_20201110_13_24_04_Prohr_flip.jpg', '/content/antispoofing_dataset/train/real/Sumit tamang40.jpg', '/content/antispoofing_dataset/train/real/ddfgfhg21.jpg', '/content/antispoofing_dataset/train/real/fjdkjk17.jpg', '/content/antispoofing_dataset/train/real/Salina Xetri2.jpg', '/content/antispoofing_dataset/train/real/20201110_145020(0)hr_flip.jpg', '/content/antispoofing_dataset/train/real/ghfdtrdtfyh9.jpg', '/content/antispoofing_dataset/train/real/Shikshya Gautam8hr_flipbrightness1.18.jpg', '/content/antispoofing_dataset/train/real/WIN_20201119_10_49_19_Pro (2)hr_flip.jpg', '/content/antispoofing_dataset/train/real/jkhjhj26.jpg', '/content/antispoofing_dataset/train/real/hghgh48.jpg', '/content/antispoofing_dataset/train/real/Salina Xetri11.jpg', '/content/antispoofing_dataset/train/real/dfjsdfjk47.jpg', '/content/antispoofing_dataset/train/real/samir ale gurung17.jpg', '/content/antispoofing_dataset/train/real/Sunil Koirala49hr_flip.jpg', '/content/antispoofing_dataset/train/real/Samir tamang26.jpg', '/content/antispoofing_dataset/train/real/dfgyhjnmk49.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal44hr_flip.jpg', '/content/antispoofing_dataset/train/real/Suraj Khanal40.jpg', '/content/antispoofing_dataset/train/real/Rihan Ale24.jpg', '/content/antispoofing_dataset/train/real/Samir Gurung5.jpg', '/content/antispoofing_dataset/train/real/Saurav Ale35.jpg', '/content/antispoofing_dataset/train/spoof/shikshya224.jpg', '/content/antispoofing_dataset/train/spoof/salina220.jpg', '/content/antispoofing_dataset/train/spoof/sulav9.jpg', '/content/antispoofing_dataset/train/spoof/sulav185.jpg', '/content/antispoofing_dataset/train/spoof/samip103.jpg', '/content/antispoofing_dataset/train/spoof/abhi347.jpg', '/content/antispoofing_dataset/train/spoof/salina147.jpg', '/content/antispoofing_dataset/train/spoof/samip337.jpg', '/content/antispoofing_dataset/train/spoof/salina63.jpg', '/content/antispoofing_dataset/train/spoof/shikshya157.jpg', '/content/antispoofing_dataset/train/spoof/rihan248.jpg', '/content/antispoofing_dataset/train/spoof/samip266.jpg', '/content/antispoofing_dataset/train/spoof/sulav67.jpg', '/content/antispoofing_dataset/train/spoof/sulav89.jpg', '/content/antispoofing_dataset/train/spoof/samip338.jpg', '/content/antispoofing_dataset/train/spoof/saurav141.jpg', '/content/antispoofing_dataset/train/spoof/abhi69.jpg', '/content/antispoofing_dataset/train/spoof/sandy145.jpg', '/content/antispoofing_dataset/train/spoof/shikshya56.jpg', '/content/antispoofing_dataset/train/spoof/sumit90.jpg', '/content/antispoofing_dataset/train/spoof/saurav163.jpg', '/content/antispoofing_dataset/train/spoof/salina139.jpg', '/content/antispoofing_dataset/train/spoof/abhi249.jpg', '/content/antispoofing_dataset/train/spoof/abhi73.jpg', '/content/antispoofing_dataset/train/spoof/abhi5.jpg']
# 50

# %% [markdown]
# <h3>Training Dataset Visualization</h3>

# %%
visualize_dataset(image_path=training_image_path,rows=5,cols=10)

# %% [markdown]
# Testing Dataset Visualization

# %%
testing_image_path = get_images(data_dir= test_dir,number_of_samples=25)
print(testing_image_path)
print(len(testing_image_path))
# Out:
# ['/content/antispoofing_dataset/test/real/WIN_20201110_13_24_05_Pro.jpg', '/content/antispoofing_dataset/test/real/Samir Gurung6.jpg', '/content/antispoofing_dataset/test/real/kjdfjsdkfj15.jpg', '/content/antispoofing_dataset/test/real/Sudeep Subedi38brightness0.73.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_13_23_55_Pro.jpg', '/content/antispoofing_dataset/test/real/dfjsdfjk40.jpg', '/content/antispoofing_dataset/test/real/dfjksjf12.jpg', '/content/antispoofing_dataset/test/real/WIN_20201119_10_49_05_Pro.jpg', '/content/antispoofing_dataset/test/real/Sudeep Subedi21brightness0.54.jpg', '/content/antispoofing_dataset/test/real/Sunil Koirala19hr_flipbrightness0.54.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam6.jpg', '/content/antispoofing_dataset/test/real/kjdfjsdkfj26.jpg', '/content/antispoofing_dataset/test/real/20201110_113513hr_flip.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam43brightness1.27.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_13_23_52_Prohr_flip.jpg', '/content/antispoofing_dataset/test/real/received_1066607767113312.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam22brightness1.3.jpg', '/content/antispoofing_dataset/test/real/dddd49.jpg', '/content/antispoofing_dataset/test/real/20201110_113526hr_flip.jpg', '/content/antispoofing_dataset/test/real/WIN_20201110_10_06_20_Prohr_flip.jpg', '/content/antispoofing_dataset/test/real/Shikshya Gautam6hr_flip.jpg', '/content/antispoofing_dataset/test/real/Sumit tamang39.jpg', '/content/antispoofing_dataset/test/real/Rihan Ale33.jpg', '/content/antispoofing_dataset/test/real/hghgh47.jpg', '/content/antispoofing_dataset/test/real/dfjsdfjk16.jpg', '/content/antispoofing_dataset/test/spoof/salina8.jpg', '/content/antispoofing_dataset/test/spoof/salina150.jpg', '/content/antispoofing_dataset/test/spoof/saurav210.jpg', '/content/antispoofing_dataset/test/spoof/samip319.jpg', '/content/antispoofing_dataset/test/spoof/abhi316.jpg', '/content/antispoofing_dataset/test/spoof/samip9.jpg', '/content/antispoofing_dataset/test/spoof/samir31.jpg', '/content/antispoofing_dataset/test/spoof/saurav320.jpg', '/content/antispoofing_dataset/test/spoof/samip95.jpg', '/content/antispoofing_dataset/test/spoof/bishal2.jpg', '/content/antispoofing_dataset/test/spoof/sulav55.jpg', '/content/antispoofing_dataset/test/spoof/sulav103.jpg', '/content/antispoofing_dataset/test/spoof/bishal8.jpg', '/content/antispoofing_dataset/test/spoof/samip126.jpg', '/content/antispoofing_dataset/test/spoof/samip258.jpg', '/content/antispoofing_dataset/test/spoof/samir29.jpg', '/content/antispoofing_dataset/test/spoof/shikshya24.jpg', '/content/antispoofing_dataset/test/spoof/saurav93.jpg', '/content/antispoofing_dataset/test/spoof/samip138.jpg', '/content/antispoofing_dataset/test/spoof/samip216.jpg', '/content/antispoofing_dataset/test/spoof/abhi22.jpg', '/content/antispoofing_dataset/test/spoof/shikshya173.jpg', '/content/antispoofing_dataset/test/spoof/saurav259.jpg', '/content/antispoofing_dataset/test/spoof/rihan83.jpg', '/content/antispoofing_dataset/test/spoof/shikshya102.jpg']
# 50

# %%
visualize_dataset(image_path=testing_image_path,rows=5,cols=10)

# %% [markdown]
# **<h3>Model Preparation</h3>**

# %% [markdown]
# <h3>Steps In Model Preparation</h3>
# <h4>1. Choosing Framework and importing necessary libraries </h2>
# <h4> 2. Load datasets and Perform image augmentations </h2>
# <h4> 3. Model Selection  </h3>
# <h4> 4. Compiling our model </h4>
# <h4> 5. Setting our model checkpoints </h4>

# %% [markdown]
# <h4>Step 1 Keras Framework </h1>

# %%
from keras.layers import Dense,Dropout,Input,Flatten
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.models import model_from_json
import json

# %% [markdown]
# <h4>Step 2 </h4>

# %%
train_datagen = ImageDataGenerator(brightness_range=(0.8,1.2),rotation_range=30,width_shift_range=0.2,height_shift_range=0.2,fill_mode='nearest',shear_range=0.2,zoom_range=0.3,rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25,shuffle=True)
# Out:
# Found 4220 images belonging to 2 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(test_dir,target_size=(160,160),color_mode='rgb',
                                                    class_mode='binary',batch_size=25)
# Out:
# Found 951 images belonging to 2 classes.

# %% [markdown]
# <h4>Step 3 Model Selection and Transfer Learning</h4>

# %%
mobilenet = MobileNetV2(weights="imagenet",include_top=False,input_tensor=Input(shape=(160,160,3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
mobilenet.trainable = False

# %%
output = Flatten()(mobilenet.output)
output = Dropout(0.3)(output)
output = Dense(units = 8,activation='relu')(output)
prediction = Dense(1,activation='sigmoid')(output)

# %%
model = Model(inputs = mobilenet.input,outputs = prediction)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 80, 80, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 80, 80, 32)   128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 80, 80, 32)   0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 80, 80, 32)   288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 80, 80, 32)   128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 80, 80, 32)   0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 80, 80, 16)   512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 80, 80, 16)   64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 80, 80, 96)   1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 80, 80, 96)   384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 80, 80, 96)   0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 81, 81, 96)   0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 40, 40, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 40, 40, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 40, 40, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 40, 40, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 40, 40, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 40, 40, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 40, 40, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 40, 40, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 40, 40, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 40, 40, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 40, 40, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 40, 40, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 40, 40, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 40, 40, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 40, 40, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 40, 40, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 40, 40, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 41, 41, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 20, 20, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 20, 20, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 20, 20, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 20, 20, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 20, 20, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 20, 20, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 20, 20, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 20, 20, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 20, 20, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 20, 20, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 20, 20, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 20, 20, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 20, 20, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 20, 20, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 20, 20, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 20, 20, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 20, 20, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 20, 20, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 20, 20, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 20, 20, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 20, 20, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 20, 20, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 20, 20, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 20, 20, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 20, 20, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 20, 20, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 21, 21, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 10, 10, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 10, 10, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 10, 10, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 10, 10, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 10, 10, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 10, 10, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 10, 10, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 10, 10, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 10, 10, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 10, 10, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 10, 10, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 10, 10, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 10, 10, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 10, 10, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 10, 10, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 10, 10, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 10, 10, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 10, 10, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 10, 10, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 10, 10, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 10, 10, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 10, 10, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 10, 10, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 10, 10, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 10, 10, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 10, 10, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 10, 10, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 10, 10, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 10, 10, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 10, 10, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 10, 10, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 10, 10, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 10, 10, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 10, 10, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 10, 10, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 10, 10, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 10, 10, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 10, 10, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 10, 10, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 10, 10, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 10, 10, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 10, 10, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 10, 10, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 10, 10, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 10, 10, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 10, 10, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 10, 10, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 10, 10, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 10, 10, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 10, 10, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 10, 10, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 10, 10, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 10, 10, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 10, 10, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 10, 10, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 10, 10, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 10, 10, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 10, 10, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 10, 10, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 10, 10, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 10, 10, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 11, 11, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 5, 5, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 5, 5, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 5, 5, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 5, 5, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 5, 5, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 5, 5, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 5, 5, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 5, 5, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 5, 5, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 5, 5, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 5, 5, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 5, 5, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 5, 5, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 5, 5, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 5, 5, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 5, 5, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 5, 5, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 5, 5, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 5, 5, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 5, 5, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 5, 5, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 5, 5, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 5, 5, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 5, 5, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 5, 5, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 5, 5, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 5, 5, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 5, 5, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 5, 5, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 5, 5, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 5, 5, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 5, 5, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 5, 5, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 5, 5, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32000)        0           out_relu[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32000)        0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            256008      dropout[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            9           dense[0][0]
# ==================================================================================================
# Total params: 2,514,001
# Trainable params: 256,017
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %% [markdown]
# <h4>Step 4 Compiling the models </h4>

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='binary_crossentropy',
  optimizer=Adam(
    learning_rate=0.000001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
),
  metrics=['accuracy']
)

# %% [markdown]
# <h4>Step 5 Setting our model checkpoints </h4>

# %%
import os
os.mkdir('/content/model_weights/')

# %%
model_checkpoint = ModelCheckpoint('./model_weights/finalyearproject_antispoofing_model_{epoch:02d}-{val_accuracy:.6f}.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True,save_weights_only=True)

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // 25,
    validation_data = valid_generator, 
    validation_steps = valid_generator.samples // 25,
    epochs = 100,
    callbacks=[model_checkpoint])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 168/168 [==============================] - 93s 228ms/step - loss: 1.0198 - accuracy: 0.5060 - val_loss: 0.7714 - val_accuracy: 0.5516
#
# Epoch 00001: val_loss improved from inf to 0.77137, saving model to ./model_weights/finalyearproject_antispoofing_model_01-0.551579.h5
# Epoch 2/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.8447 - accuracy: 0.5436 - val_loss: 0.6863 - val_accuracy: 0.6032
#
# Epoch 00002: val_loss improved from 0.77137 to 0.68629, saving model to ./model_weights/finalyearproject_antispoofing_model_02-0.603158.h5
# Epoch 3/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.7575 - accuracy: 0.5946 - val_loss: 0.6297 - val_accuracy: 0.6621
#
# Epoch 00003: val_loss improved from 0.68629 to 0.62971, saving model to ./model_weights/finalyearproject_antispoofing_model_03-0.662105.h5
# Epoch 4/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.6996 - accuracy: 0.6223 - val_loss: 0.5750 - val_accuracy: 0.7126
#
# Epoch 00004: val_loss improved from 0.62971 to 0.57500, saving model to ./model_weights/finalyearproject_antispoofing_model_04-0.712632.h5
# Epoch 5/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.6469 - accuracy: 0.6654 - val_loss: 0.5303 - val_accuracy: 0.7495
#
# Epoch 00005: val_loss improved from 0.57500 to 0.53029, saving model to ./model_weights/finalyearproject_antispoofing_model_05-0.749474.h5
# Epoch 6/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.6264 - accuracy: 0.6693 - val_loss: 0.4976 - val_accuracy: 0.7842
#
# Epoch 00006: val_loss improved from 0.53029 to 0.49757, saving model to ./model_weights/finalyearproject_antispoofing_model_06-0.784211.h5
# Epoch 7/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.5934 - accuracy: 0.6987 - val_loss: 0.4656 - val_accuracy: 0.8084
#
# Epoch 00007: val_loss improved from 0.49757 to 0.46565, saving model to ./model_weights/finalyearproject_antispoofing_model_07-0.808421.h5
# Epoch 8/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.5796 - accuracy: 0.7037 - val_loss: 0.4350 - val_accuracy: 0.8389
#
# Epoch 00008: val_loss improved from 0.46565 to 0.43504, saving model to ./model_weights/finalyearproject_antispoofing_model_08-0.838947.h5
# Epoch 9/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.5198 - accuracy: 0.7558 - val_loss: 0.4100 - val_accuracy: 0.8474
#
# Epoch 00009: val_loss improved from 0.43504 to 0.41000, saving model to ./model_weights/finalyearproject_antispoofing_model_09-0.847368.h5
# Epoch 10/100
# 168/168 [==============================] - 35s 205ms/step - loss: 0.5028 - accuracy: 0.7659 - val_loss: 0.3859 - val_accuracy: 0.8589
#
# Epoch 00010: val_loss improved from 0.41000 to 0.38592, saving model to ./model_weights/finalyearproject_antispoofing_model_10-0.858947.h5
# Epoch 11/100
# 168/168 [==============================] - 35s 205ms/step - loss: 0.4889 - accuracy: 0.7743 - val_loss: 0.3636 - val_accuracy: 0.8737
#
# Epoch 00011: val_loss improved from 0.38592 to 0.36364, saving model to ./model_weights/finalyearproject_antispoofing_model_11-0.873684.h5
# Epoch 12/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.4650 - accuracy: 0.7884 - val_loss: 0.3440 - val_accuracy: 0.8832
#
# Epoch 00012: val_loss improved from 0.36364 to 0.34404, saving model to ./model_weights/finalyearproject_antispoofing_model_12-0.883158.h5
# Epoch 13/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.4355 - accuracy: 0.8020 - val_loss: 0.3264 - val_accuracy: 0.8895
#
# Epoch 00013: val_loss improved from 0.34404 to 0.32643, saving model to ./model_weights/finalyearproject_antispoofing_model_13-0.889474.h5
# Epoch 14/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.3986 - accuracy: 0.8299 - val_loss: 0.3089 - val_accuracy: 0.8979
#
# Epoch 00014: val_loss improved from 0.32643 to 0.30893, saving model to ./model_weights/finalyearproject_antispoofing_model_14-0.897895.h5
# Epoch 15/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.3754 - accuracy: 0.8327 - val_loss: 0.2943 - val_accuracy: 0.9000
#
# Epoch 00015: val_loss improved from 0.30893 to 0.29427, saving model to ./model_weights/finalyearproject_antispoofing_model_15-0.900000.h5
# Epoch 16/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.3806 - accuracy: 0.8328 - val_loss: 0.2807 - val_accuracy: 0.9021
#
# Epoch 00016: val_loss improved from 0.29427 to 0.28071, saving model to ./model_weights/finalyearproject_antispoofing_model_16-0.902105.h5
# Epoch 17/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.3620 - accuracy: 0.8425 - val_loss: 0.2672 - val_accuracy: 0.9095
#
# Epoch 00017: val_loss improved from 0.28071 to 0.26725, saving model to ./model_weights/finalyearproject_antispoofing_model_17-0.909474.h5
# Epoch 18/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.3676 - accuracy: 0.8435 - val_loss: 0.2550 - val_accuracy: 0.9126
#
# Epoch 00018: val_loss improved from 0.26725 to 0.25500, saving model to ./model_weights/finalyearproject_antispoofing_model_18-0.912632.h5
# Epoch 19/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.3494 - accuracy: 0.8517 - val_loss: 0.2467 - val_accuracy: 0.9158
#
# Epoch 00019: val_loss improved from 0.25500 to 0.24675, saving model to ./model_weights/finalyearproject_antispoofing_model_19-0.915789.h5
# Epoch 20/100
# 168/168 [==============================] - 35s 208ms/step - loss: 0.3315 - accuracy: 0.8644 - val_loss: 0.2356 - val_accuracy: 0.9179
#
# Epoch 00020: val_loss improved from 0.24675 to 0.23559, saving model to ./model_weights/finalyearproject_antispoofing_model_20-0.917895.h5
# Epoch 21/100
# 168/168 [==============================] - 35s 207ms/step - loss: 0.3255 - accuracy: 0.8577 - val_loss: 0.2272 - val_accuracy: 0.9200
#
# Epoch 00021: val_loss improved from 0.23559 to 0.22721, saving model to ./model_weights/finalyearproject_antispoofing_model_21-0.920000.h5
# Epoch 22/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.3142 - accuracy: 0.8669 - val_loss: 0.2206 - val_accuracy: 0.9242
#
# Epoch 00022: val_loss improved from 0.22721 to 0.22062, saving model to ./model_weights/finalyearproject_antispoofing_model_22-0.924211.h5
# Epoch 23/100
# 168/168 [==============================] - 35s 210ms/step - loss: 0.2939 - accuracy: 0.8738 - val_loss: 0.2161 - val_accuracy: 0.9253
#
# Epoch 00023: val_loss improved from 0.22062 to 0.21606, saving model to ./model_weights/finalyearproject_antispoofing_model_23-0.925263.h5
# Epoch 24/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.3032 - accuracy: 0.8682 - val_loss: 0.2071 - val_accuracy: 0.9305
#
# Epoch 00024: val_loss improved from 0.21606 to 0.20710, saving model to ./model_weights/finalyearproject_antispoofing_model_24-0.930526.h5
# Epoch 25/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2949 - accuracy: 0.8743 - val_loss: 0.1983 - val_accuracy: 0.9358
#
# Epoch 00025: val_loss improved from 0.20710 to 0.19833, saving model to ./model_weights/finalyearproject_antispoofing_model_25-0.935789.h5
# Epoch 26/100
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2912 - accuracy: 0.8828 - val_loss: 0.1957 - val_accuracy: 0.9358
#
# Epoch 00026: val_loss improved from 0.19833 to 0.19568, saving model to ./model_weights/finalyearproject_antispoofing_model_26-0.935789.h5
# Epoch 27/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.2728 - accuracy: 0.8883 - val_loss: 0.1867 - val_accuracy: 0.9411
#
# Epoch 00027: val_loss improved from 0.19568 to 0.18674, saving model to ./model_weights/finalyearproject_antispoofing_model_27-0.941053.h5
# Epoch 28/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.2706 - accuracy: 0.8928 - val_loss: 0.1843 - val_accuracy: 0.9389
#
# Epoch 00028: val_loss improved from 0.18674 to 0.18435, saving model to ./model_weights/finalyearproject_antispoofing_model_28-0.938947.h5
# Epoch 29/100
# 168/168 [==============================] - 33s 198ms/step - loss: 0.2506 - accuracy: 0.9057 - val_loss: 0.1770 - val_accuracy: 0.9400
#
# Epoch 00029: val_loss improved from 0.18435 to 0.17696, saving model to ./model_weights/finalyearproject_antispoofing_model_29-0.940000.h5
# Epoch 30/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2747 - accuracy: 0.8933 - val_loss: 0.1768 - val_accuracy: 0.9358
#
# Epoch 00030: val_loss improved from 0.17696 to 0.17684, saving model to ./model_weights/finalyearproject_antispoofing_model_30-0.935789.h5
# Epoch 31/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2345 - accuracy: 0.9010 - val_loss: 0.1710 - val_accuracy: 0.9411
#
# Epoch 00031: val_loss improved from 0.17684 to 0.17098, saving model to ./model_weights/finalyearproject_antispoofing_model_31-0.941053.h5
# Epoch 32/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.2384 - accuracy: 0.8967 - val_loss: 0.1664 - val_accuracy: 0.9400
#
# Epoch 00032: val_loss improved from 0.17098 to 0.16642, saving model to ./model_weights/finalyearproject_antispoofing_model_32-0.940000.h5
# Epoch 33/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.2336 - accuracy: 0.9005 - val_loss: 0.1615 - val_accuracy: 0.9411
#
# Epoch 00033: val_loss improved from 0.16642 to 0.16152, saving model to ./model_weights/finalyearproject_antispoofing_model_33-0.941053.h5
# Epoch 34/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2342 - accuracy: 0.9033 - val_loss: 0.1567 - val_accuracy: 0.9432
#
# Epoch 00034: val_loss improved from 0.16152 to 0.15668, saving model to ./model_weights/finalyearproject_antispoofing_model_34-0.943158.h5
# Epoch 35/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2329 - accuracy: 0.9022 - val_loss: 0.1548 - val_accuracy: 0.9442
#
# Epoch 00035: val_loss improved from 0.15668 to 0.15479, saving model to ./model_weights/finalyearproject_antispoofing_model_35-0.944211.h5
# Epoch 36/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.2176 - accuracy: 0.9108 - val_loss: 0.1528 - val_accuracy: 0.9421
#
# Epoch 00036: val_loss improved from 0.15479 to 0.15278, saving model to ./model_weights/finalyearproject_antispoofing_model_36-0.942105.h5
# Epoch 37/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.2243 - accuracy: 0.9029 - val_loss: 0.1501 - val_accuracy: 0.9442
#
# Epoch 00037: val_loss improved from 0.15278 to 0.15007, saving model to ./model_weights/finalyearproject_antispoofing_model_37-0.944211.h5
# Epoch 38/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.2020 - accuracy: 0.9232 - val_loss: 0.1496 - val_accuracy: 0.9432
#
# Epoch 00038: val_loss improved from 0.15007 to 0.14956, saving model to ./model_weights/finalyearproject_antispoofing_model_38-0.943158.h5
# Epoch 39/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2261 - accuracy: 0.9117 - val_loss: 0.1423 - val_accuracy: 0.9463
#
# Epoch 00039: val_loss improved from 0.14956 to 0.14235, saving model to ./model_weights/finalyearproject_antispoofing_model_39-0.946316.h5
# Epoch 40/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.2305 - accuracy: 0.9085 - val_loss: 0.1402 - val_accuracy: 0.9474
#
# Epoch 00040: val_loss improved from 0.14235 to 0.14016, saving model to ./model_weights/finalyearproject_antispoofing_model_40-0.947368.h5
# Epoch 41/100
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2054 - accuracy: 0.9129 - val_loss: 0.1370 - val_accuracy: 0.9474
#
# Epoch 00041: val_loss improved from 0.14016 to 0.13704, saving model to ./model_weights/finalyearproject_antispoofing_model_41-0.947368.h5
# Epoch 42/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.2146 - accuracy: 0.9106 - val_loss: 0.1349 - val_accuracy: 0.9474
#
# Epoch 00042: val_loss improved from 0.13704 to 0.13486, saving model to ./model_weights/finalyearproject_antispoofing_model_42-0.947368.h5
# Epoch 43/100
# 168/168 [==============================] - 34s 202ms/step - loss: 0.2003 - accuracy: 0.9190 - val_loss: 0.1346 - val_accuracy: 0.9484
#
# Epoch 00043: val_loss improved from 0.13486 to 0.13460, saving model to ./model_weights/finalyearproject_antispoofing_model_43-0.948421.h5
# Epoch 44/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.2023 - accuracy: 0.9137 - val_loss: 0.1305 - val_accuracy: 0.9495
#
# Epoch 00044: val_loss improved from 0.13460 to 0.13053, saving model to ./model_weights/finalyearproject_antispoofing_model_44-0.949474.h5
# Epoch 45/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1919 - accuracy: 0.9267 - val_loss: 0.1279 - val_accuracy: 0.9495
#
# Epoch 00045: val_loss improved from 0.13053 to 0.12787, saving model to ./model_weights/finalyearproject_antispoofing_model_45-0.949474.h5
# Epoch 46/100
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1901 - accuracy: 0.9249 - val_loss: 0.1314 - val_accuracy: 0.9516
#
# Epoch 00046: val_loss did not improve from 0.12787
# Epoch 47/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1959 - accuracy: 0.9256 - val_loss: 0.1285 - val_accuracy: 0.9516
#
# Epoch 00047: val_loss did not improve from 0.12787
# Epoch 48/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1779 - accuracy: 0.9340 - val_loss: 0.1215 - val_accuracy: 0.9526
#
# Epoch 00048: val_loss improved from 0.12787 to 0.12154, saving model to ./model_weights/finalyearproject_antispoofing_model_48-0.952632.h5
# Epoch 49/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1707 - accuracy: 0.9360 - val_loss: 0.1185 - val_accuracy: 0.9547
#
# Epoch 00049: val_loss improved from 0.12154 to 0.11854, saving model to ./model_weights/finalyearproject_antispoofing_model_49-0.954737.h5
# Epoch 50/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1808 - accuracy: 0.9283 - val_loss: 0.1181 - val_accuracy: 0.9547
#
# Epoch 00050: val_loss improved from 0.11854 to 0.11813, saving model to ./model_weights/finalyearproject_antispoofing_model_50-0.954737.h5
# Epoch 51/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1749 - accuracy: 0.9360 - val_loss: 0.1196 - val_accuracy: 0.9526
#
# Epoch 00051: val_loss did not improve from 0.11813
# Epoch 52/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1719 - accuracy: 0.9369 - val_loss: 0.1155 - val_accuracy: 0.9600
#
# Epoch 00052: val_loss improved from 0.11813 to 0.11549, saving model to ./model_weights/finalyearproject_antispoofing_model_52-0.960000.h5
# Epoch 53/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1873 - accuracy: 0.9260 - val_loss: 0.1101 - val_accuracy: 0.9600
#
# Epoch 00053: val_loss improved from 0.11549 to 0.11008, saving model to ./model_weights/finalyearproject_antispoofing_model_53-0.960000.h5
# Epoch 54/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1903 - accuracy: 0.9292 - val_loss: 0.1106 - val_accuracy: 0.9611
#
# Epoch 00054: val_loss did not improve from 0.11008
# Epoch 55/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1681 - accuracy: 0.9334 - val_loss: 0.1119 - val_accuracy: 0.9589
#
# Epoch 00055: val_loss did not improve from 0.11008
# Epoch 56/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1796 - accuracy: 0.9240 - val_loss: 0.1039 - val_accuracy: 0.9621
#
# Epoch 00056: val_loss improved from 0.11008 to 0.10393, saving model to ./model_weights/finalyearproject_antispoofing_model_56-0.962105.h5
# Epoch 57/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1723 - accuracy: 0.9316 - val_loss: 0.1009 - val_accuracy: 0.9632
#
# Epoch 00057: val_loss improved from 0.10393 to 0.10088, saving model to ./model_weights/finalyearproject_antispoofing_model_57-0.963158.h5
# Epoch 58/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1657 - accuracy: 0.9362 - val_loss: 0.1045 - val_accuracy: 0.9611
#
# Epoch 00058: val_loss did not improve from 0.10088
# Epoch 59/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1614 - accuracy: 0.9318 - val_loss: 0.0994 - val_accuracy: 0.9632
#
# Epoch 00059: val_loss improved from 0.10088 to 0.09944, saving model to ./model_weights/finalyearproject_antispoofing_model_59-0.963158.h5
# Epoch 60/100
# 168/168 [==============================] - 34s 201ms/step - loss: 0.1549 - accuracy: 0.9385 - val_loss: 0.1007 - val_accuracy: 0.9642
#
# Epoch 00060: val_loss did not improve from 0.09944
# Epoch 61/100
# 168/168 [==============================] - 34s 202ms/step - loss: 0.1433 - accuracy: 0.9497 - val_loss: 0.1000 - val_accuracy: 0.9621
#
# Epoch 00061: val_loss did not improve from 0.09944
# Epoch 62/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1690 - accuracy: 0.9343 - val_loss: 0.0969 - val_accuracy: 0.9642
#
# Epoch 00062: val_loss improved from 0.09944 to 0.09687, saving model to ./model_weights/finalyearproject_antispoofing_model_62-0.964211.h5
# Epoch 63/100
# 168/168 [==============================] - 34s 199ms/step - loss: 0.1460 - accuracy: 0.9466 - val_loss: 0.0956 - val_accuracy: 0.9642
#
# Epoch 00063: val_loss improved from 0.09687 to 0.09558, saving model to ./model_weights/finalyearproject_antispoofing_model_63-0.964211.h5
# Epoch 64/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1587 - accuracy: 0.9412 - val_loss: 0.0914 - val_accuracy: 0.9653
#
# Epoch 00064: val_loss improved from 0.09558 to 0.09135, saving model to ./model_weights/finalyearproject_antispoofing_model_64-0.965263.h5
# Epoch 65/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1583 - accuracy: 0.9406 - val_loss: 0.0944 - val_accuracy: 0.9642
#
# Epoch 00065: val_loss did not improve from 0.09135
# Epoch 66/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1387 - accuracy: 0.9472 - val_loss: 0.0921 - val_accuracy: 0.9653
#
# Epoch 00066: val_loss did not improve from 0.09135
# Epoch 67/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1493 - accuracy: 0.9385 - val_loss: 0.0887 - val_accuracy: 0.9663
#
# Epoch 00067: val_loss improved from 0.09135 to 0.08866, saving model to ./model_weights/finalyearproject_antispoofing_model_67-0.966316.h5
# Epoch 68/100
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1537 - accuracy: 0.9501 - val_loss: 0.0861 - val_accuracy: 0.9674
#
# Epoch 00068: val_loss improved from 0.08866 to 0.08610, saving model to ./model_weights/finalyearproject_antispoofing_model_68-0.967368.h5
# Epoch 69/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1432 - accuracy: 0.9473 - val_loss: 0.0860 - val_accuracy: 0.9674
#
# Epoch 00069: val_loss improved from 0.08610 to 0.08602, saving model to ./model_weights/finalyearproject_antispoofing_model_69-0.967368.h5
# Epoch 70/100
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1504 - accuracy: 0.9426 - val_loss: 0.0876 - val_accuracy: 0.9663
#
# Epoch 00070: val_loss did not improve from 0.08602
# Epoch 71/100
# 168/168 [==============================] - 33s 197ms/step - loss: 0.1338 - accuracy: 0.9524 - val_loss: 0.0843 - val_accuracy: 0.9663
#
# Epoch 00071: val_loss improved from 0.08602 to 0.08429, saving model to ./model_weights/finalyearproject_antispoofing_model_71-0.966316.h5
# Epoch 72/100
# 168/168 [==============================] - 33s 196ms/step - loss: 0.1452 - accuracy: 0.9433 - val_loss: 0.0846 - val_accuracy: 0.9663
#
# Epoch 00072: val_loss did not improve from 0.08429
# Epoch 73/100
# 168/168 [==============================] - 33s 195ms/step - loss: 0.1426 - accuracy: 0.9491 - val_loss: 0.0832 - val_accuracy: 0.9663
#
# Epoch 00073: val_loss improved from 0.08429 to 0.08323, saving model to ./model_weights/finalyearproject_antispoofing_model_73-0.966316.h5
# Epoch 74/100
# 168/168 [==============================] - 33s 197ms/step - loss: 0.1423 - accuracy: 0.9453 - val_loss: 0.0812 - val_accuracy: 0.9663
#
# Epoch 00074: val_loss improved from 0.08323 to 0.08121, saving model to ./model_weights/finalyearproject_antispoofing_model_74-0.966316.h5
# Epoch 75/100
# 168/168 [==============================] - 33s 198ms/step - loss: 0.1275 - accuracy: 0.9472 - val_loss: 0.0806 - val_accuracy: 0.9663
#
# Epoch 00075: val_loss improved from 0.08121 to 0.08063, saving model to ./model_weights/finalyearproject_antispoofing_model_75-0.966316.h5
# Epoch 76/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1356 - accuracy: 0.9482 - val_loss: 0.0788 - val_accuracy: 0.9674
#
# Epoch 00076: val_loss improved from 0.08063 to 0.07879, saving model to ./model_weights/finalyearproject_antispoofing_model_76-0.967368.h5
# Epoch 77/100
# 168/168 [==============================] - 35s 209ms/step - loss: 0.1336 - accuracy: 0.9538 - val_loss: 0.0788 - val_accuracy: 0.9663
#
# Epoch 00077: val_loss did not improve from 0.07879
# Epoch 78/100
# 168/168 [==============================] - 35s 209ms/step - loss: 0.1278 - accuracy: 0.9517 - val_loss: 0.0755 - val_accuracy: 0.9684
#
# Epoch 00078: val_loss improved from 0.07879 to 0.07547, saving model to ./model_weights/finalyearproject_antispoofing_model_78-0.968421.h5
# Epoch 79/100
# 168/168 [==============================] - 33s 199ms/step - loss: 0.1276 - accuracy: 0.9549 - val_loss: 0.0769 - val_accuracy: 0.9674
#
# Epoch 00079: val_loss did not improve from 0.07547
# Epoch 80/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1332 - accuracy: 0.9504 - val_loss: 0.0762 - val_accuracy: 0.9684
#
# Epoch 00080: val_loss did not improve from 0.07547
# Epoch 81/100
# 168/168 [==============================] - 34s 200ms/step - loss: 0.1327 - accuracy: 0.9445 - val_loss: 0.0738 - val_accuracy: 0.9705
#
# Epoch 00081: val_loss improved from 0.07547 to 0.07384, saving model to ./model_weights/finalyearproject_antispoofing_model_81-0.970526.h5
# Epoch 82/100
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1261 - accuracy: 0.9515 - val_loss: 0.0741 - val_accuracy: 0.9705
#
# Epoch 00082: val_loss did not improve from 0.07384
# Epoch 83/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1303 - accuracy: 0.9498 - val_loss: 0.0761 - val_accuracy: 0.9684
#
# Epoch 00083: val_loss did not improve from 0.07384
# Epoch 84/100
# 168/168 [==============================] - 34s 203ms/step - loss: 0.1213 - accuracy: 0.9589 - val_loss: 0.0729 - val_accuracy: 0.9705
#
# Epoch 00084: val_loss improved from 0.07384 to 0.07286, saving model to ./model_weights/finalyearproject_antispoofing_model_84-0.970526.h5
# Epoch 85/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1479 - accuracy: 0.9444 - val_loss: 0.0727 - val_accuracy: 0.9705
#
# Epoch 00085: val_loss improved from 0.07286 to 0.07272, saving model to ./model_weights/finalyearproject_antispoofing_model_85-0.970526.h5
# Epoch 86/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1141 - accuracy: 0.9591 - val_loss: 0.0729 - val_accuracy: 0.9716
#
# Epoch 00086: val_loss did not improve from 0.07272
# Epoch 87/100
# 168/168 [==============================] - 34s 204ms/step - loss: 0.1350 - accuracy: 0.9491 - val_loss: 0.0696 - val_accuracy: 0.9726
#
# Epoch 00087: val_loss improved from 0.07272 to 0.06961, saving model to ./model_weights/finalyearproject_antispoofing_model_87-0.972632.h5
# Epoch 88/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1340 - accuracy: 0.9484 - val_loss: 0.0695 - val_accuracy: 0.9737
#
# Epoch 00088: val_loss improved from 0.06961 to 0.06952, saving model to ./model_weights/finalyearproject_antispoofing_model_88-0.973684.h5
# Epoch 89/100
# 168/168 [==============================] - 35s 209ms/step - loss: 0.1209 - accuracy: 0.9557 - val_loss: 0.0702 - val_accuracy: 0.9726
#
# Epoch 00089: val_loss did not improve from 0.06952
# Epoch 90/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1205 - accuracy: 0.9575 - val_loss: 0.0680 - val_accuracy: 0.9737
#
# Epoch 00090: val_loss improved from 0.06952 to 0.06801, saving model to ./model_weights/finalyearproject_antispoofing_model_90-0.973684.h5
# Epoch 91/100
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1237 - accuracy: 0.9492 - val_loss: 0.0712 - val_accuracy: 0.9726
#
# Epoch 00091: val_loss did not improve from 0.06801
# Epoch 92/100
# 168/168 [==============================] - 34s 205ms/step - loss: 0.1273 - accuracy: 0.9588 - val_loss: 0.0684 - val_accuracy: 0.9726
#
# Epoch 00092: val_loss did not improve from 0.06801
# Epoch 93/100
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1080 - accuracy: 0.9575 - val_loss: 0.0658 - val_accuracy: 0.9737
#
# Epoch 00093: val_loss improved from 0.06801 to 0.06580, saving model to ./model_weights/finalyearproject_antispoofing_model_93-0.973684.h5
# Epoch 94/100
# 168/168 [==============================] - 35s 209ms/step - loss: 0.1242 - accuracy: 0.9567 - val_loss: 0.0634 - val_accuracy: 0.9747
#
# Epoch 00094: val_loss improved from 0.06580 to 0.06342, saving model to ./model_weights/finalyearproject_antispoofing_model_94-0.974737.h5
# Epoch 95/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1036 - accuracy: 0.9616 - val_loss: 0.0671 - val_accuracy: 0.9726
#
# Epoch 00095: val_loss did not improve from 0.06342
# Epoch 96/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1275 - accuracy: 0.9500 - val_loss: 0.0635 - val_accuracy: 0.9737
#
# Epoch 00096: val_loss did not improve from 0.06342
# Epoch 97/100
# 168/168 [==============================] - 35s 207ms/step - loss: 0.1044 - accuracy: 0.9621 - val_loss: 0.0607 - val_accuracy: 0.9768
#
# Epoch 00097: val_loss improved from 0.06342 to 0.06074, saving model to ./model_weights/finalyearproject_antispoofing_model_97-0.976842.h5
# Epoch 98/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1098 - accuracy: 0.9576 - val_loss: 0.0630 - val_accuracy: 0.9737
#
# Epoch 00098: val_loss did not improve from 0.06074
# Epoch 99/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1161 - accuracy: 0.9549 - val_loss: 0.0637 - val_accuracy: 0.9737
#
# Epoch 00099: val_loss did not improve from 0.06074
# Epoch 100/100
# 168/168 [==============================] - 35s 206ms/step - loss: 0.1149 - accuracy: 0.9584 - val_loss: 0.0631 - val_accuracy: 0.9737
#
# Epoch 00100: val_loss did not improve from 0.06074

# %%
# serialize model to JSON
model_json = model.to_json()
with open("finalyearproject_antispoofing_model_mobilenet.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
epochs = range(1,101)
plt.plot(epochs,train_accuracy,'g',label='Training Accuracy')
plt.plot(epochs,validation_accuracy,'b',label='Validation Accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,101)
plt.plot(epochs,train_loss,'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.preprocessing import image
import numpy as np
def check_fakes(path,category_type):
  predictor = {}
  path= os.path.join(path,category_type)
  for img in os.listdir(path):
    try:
      img = image.load_img(os.path.join(path,img),target_size=(160,160))
      img = image.img_to_array(img)
      img = np.expand_dims(img,axis=0)
      img = img / 255.0
      prediction = model.predict(img)
      if prediction > 0.5:
        prediction_class = 1
      else:
        prediction_class = 0
      result = categories[prediction_class]
      if result not in predictor:
        predictor[result] = 1
      else:
        predictor[result] += 1
    except Exception as e:
      pass
  return predictor

# %%
check_fakes(test_dir,categories[1])
# Out:
# {'real': 19, 'spoof': 455}

# %%
check_fakes(test_dir,categories[0])
# Out:
# {'real': 471, 'spoof': 6}

# %%
(19+6)/(19+455+471+6)*100
# Out:
# 2.6288117770767614

# %%
100-2.6288
# Out:
# 97.3712
